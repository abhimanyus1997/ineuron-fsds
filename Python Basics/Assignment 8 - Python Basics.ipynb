# %% [markdown]
# # Assignment 8 - Python Basics

# %% [markdown]
# ## 1. Is the Python Standard Library included with PyInputPlus?
# **Ans:** No, It need to be installed using
# ```Python
# !pip install PyInputPlus
#
# ```
#
# >**Note:** `PyInputPlus` is a Python module used for taking inputs with additional validation features. PyInputPlus will keep asking the user for text until they enter valid input.

# %% [markdown]
# `![image.png](attachment:5908a277-e35f-48b4-b967-5cbafc145bd7.png)

# %% [markdown]
# ![image.png](attachment:dfc002c4-462d-4fa4-901b-7576c8618033.png)

# %% [markdown]
# ## 2. Why is PyInputPlus commonly imported with import pyinputplus as pypi?
# **Ans:** Because it makes calling the class methods name smaller by using a class alias.
# ex - `import pyinputplus as pyip`

# %% [markdown]
# ## 3. How do you distinguish between inputInt() and inputFloat()?

# %% [markdown]
# * `inputInt()` : Accepts an integer value. This also takes additional parameters ‘min’, ‘max’, ‘greaterThan’ and ‘lessThan’  for bounds. Returns an int.inputInt() : Accepts an integer value. This also takes additional parameters ‘min’, ‘max’, ‘greaterThan’ and ‘lessThan’  for bounds. Returns an int.
#
# * `inputFloat()` : Accepts a floating-point numeric value. Also takes additional ‘min’, ‘max’, ‘greaterThan’ and ‘lessThan’  parameters. Returns a float.

# %% [markdown]
# ## 4. Using PyInputPlus, how do you ensure that the user enters a whole number between 0 and 99?

# %%
import pyinputplus as pyip
# integer input with limited number of tries
inp = pyip.inputInt(prompt = "\nEnter No b/w 0 to 99: ", min = 0, max = 99)
print("Validated Input:",inp)
# Out:
# Enter No b/w 0 to 99:
#  t
# 't' is not an integer.
#
# Enter No b/w 0 to 99:
#  -1
# Number must be at minimum 0.
#
# Enter No b/w 0 to 99:
#  1838
# Number must be at maximum 99.
#
# Enter No b/w 0 to 99:
#  1.41
# '1.41' is not an integer.
#
# Enter No b/w 0 to 99:
#  23
# Validated Input: 23

# %% [markdown]
# ## 5. What is transferred to the keyword arguments allowRegexes and blockRegexes?
# We use `allowRegexes` and `blockRegexes` keyword arguments to take list of regular expression strings to determine what the pyinputplus function will reject or accept valid input

# %% [markdown]
# ## 6. If a blank input is entered three times, what does inputStr(limit=3) do?
# The statement `inputStr(limit=3)` will throw two exceptions `ValidationException` and `RetryLimitException`. The first exception is thrown because blank values are not allowed by `inputStr()` function by default. it we want to consider blank values as valid input, we have to set `blank=True`.
#
# The second exception is occured because we have reached the max limit we have specified by using `limit` parameter. inorder to avoid this exception we can use default parameter to return a default value when max limit is reached.

# %%
str_input = pyip.inputStr(limit=3)
print(str_input)
# Out:
# Blank values are not allowed.
# Blank values are not allowed.
# Blank values are not allowed.
# ---------------------------------------------------------------------------
# ValidationException                       Traceback (most recent call last)
# File C:\Python310\lib\site-packages\pyinputplus\__init__.py:167, in _genericInput(prompt, default, timeout, limit, applyFunc, validationFunc, postValidateApplyFunc, passwordMask)
#     166 try:
# --> 167     possibleNewUserInput = validationFunc(
#     168         userInput
#     169     )  # If validation fails, this function will raise an exception. Returns an updated value to use as user input (e.g. stripped of whitespace, etc.)
#     170     if possibleNewUserInput is not None:
#
# File C:\Python310\lib\site-packages\pyinputplus\__init__.py:243, in inputStr.<locals>.<lambda>(value)
#     241 pysv._validateGenericParameters(blank, strip, allowRegexes, blockRegexes)
# --> 243 validationFunc = lambda value: pysv._prevalidationCheck(
# ...

# %% [markdown]
# ## 7. If blank input is entered three times, what does inputStr(limit=3, default=&#39;hello&#39;) do?

# %% [markdown]
# Since the default parameter is set to hello. after blank input is entered three times instead of raising `RetryLimitException` exception. the function will return hello as response to the calling function

# %%
str_input = pyip.inputStr(limit=3, default='hello')
print(str_input)
# Out:
# Blank values are not allowed.
# Blank values are not allowed.
# Blank values are not allowed.
# hello
